# %%
# reading in packages
import pandas as pd
from mapbox import Geocoder
import numpy as np
import requests
import json
from math import isnan

# %%
# Reading in Locations Dataset
vic_markets = pd.read_csv('tmpKqjfH4markets.csv')

# developer access token
MAPBOX_ACCESS_TOKEN = 'pk.eyJ1IjoiZGFzMDAwMSIsImEiOiJjazl3bHVxMzgwYXQ4M2lta2JoYmRraTZ4In0.0wctA_QOgf_1eIdZzmfcHA'
# Create full address
#vic_markets['Full Address'] = vic_markets['Name'] + ' ' + vic_markets['Address'] + ' ' + vic_markets['Suburb']
# Instantiate Geocoder with the access token
geocoder = Geocoder(access_token=MAPBOX_ACCESS_TOKEN)

# %%
lat = []
lon = []
error = []

for row in vic_markets.itertuples():
    try:
        response = geocoder.forward(str(row['Full Address']), country=['au'], limit = 1) # call mapbox
        coordinates = response.json()['features'][0]['geometry']['coordinates'] # get coordinates
        lat.append(coordinates[1]) # store latitude
        lon.append(coordinates[0]) # store coordinates
    except:
        try: # if you get an error, try with the name instead
            response = geocoder.forward(str(row.Name), country=['au'], limit = 1) # call mapbox
            coordinates = response.json()['features'][0]['geometry']['coordinates'] # get coordinates
            lat.append(coordinates[1]) # store latitude
            lon.append(coordinates[0]) # store coordinates
        except:
            try: # if that fails, try with postcode
                response = geocoder.forward(str(int(row.Postcode)), country=['au'], limit = 1) # call mapbox
                coordinates = response.json()['features'][0]['geometry']['coordinates'] # get coordinates
                lat.append(coordinates[1]) # store latitude
                lon.append(coordinates[0]) # store coordinates
            except:
                print("Error!")
                error.append(row)

# %%
# store into dataframe
vic_markets['lat'] = lat
vic_markets['lon'] = lon

# %% [markdown]
# # Attempt to do a JOIN on postcodes dataset

# %%
postcodes_csv = pd.read_csv('australian_postcodes.csv')
postcodes_csv.drop_duplicates(subset=['postcode'], inplace = True) # get rid of duplicate postcodes, we just want to know 1 lat long

result = pd.merge(vic_markets, postcodes_csv[['postcode', 'long', 'lat']], left_on = ['Postcode'], right_on = ['postcode'], how = 'left')
result.drop(['postcode'], axis = 1, inplace = True)

# %%
# Use mapbox for the outliers ;)
lat = []
lon = []
error = []

for row in result[np.isnan(result['Postcode'])].itertuples():
    try:
        response = geocoder.forward(str(row.Name), country=['au'], limit = 1) # call mapbox
        coordinates = response.json()['features'][0]['geometry']['coordinates'] # get coordinates
        lat.append(coordinates[1]) # store latitude
        lon.append(coordinates[0]) # store coordinates
    except:
        try: # if you get an error, try with the name instead
            response = geocoder.forward(str(row.Address), country=['au'], limit = 1) # call mapbox
            coordinates = response.json()['features'][0]['geometry']['coordinates'] # get coordinates
            lat.append(coordinates[1]) # store latitude
            lon.append(coordinates[0]) # store coordinates
        except:
            try: # if that fails, try with postcode
                response = geocoder.forward(str(row.Suburb), country=['au'], limit = 1) # call mapbox
                coordinates = response.json()['features'][0]['geometry']['coordinates'] # get coordinates
                lat.append(coordinates[1]) # store latitude
                lon.append(coordinates[0]) # store coordinates
            except:
                print("Error!")
                error.append(row)

result.loc[np.isnan(result['Postcode']),'lat'] = lat
result.loc[np.isnan(result['Postcode']),'long'] = lon

# %%
result.to_csv('vic_markets.csv')

# %% [markdown]
# # Uploading to API
# Now that we have latitude and longitude for all locations, we should upload this to our Cosmos DB (using our API so that the locations are available)

# %%
# cleanup result
result.rename(columns={'Business Category':'business_category'}, inplace=True)
result = result.where(pd.notnull(result), None)

# %%
# format a row into the format required for the database
result.iloc[0]
# Out:
# Name                 Ararat Seasonal Farmers' Market
# Address                             Lakeside Gardens
# Suburb                                        Ararat
# Postcode                                        3377
# State                                            VIC
# business_category                  Fresh Food Market
# LGA                                      Ararat (RC)
# Region                              Grampians Region
# long                                         142.957
# lat                                         -37.2315
# Name: 0, dtype: object

# %%
# iterate on each row in the addresses dataset
error = []
for row in result.itertuples():
    # extract variables
    name = row.Name
    address = row.Address
    suburb = row.Suburb
    state = row.State
    business_category = row.business_category
    lga = row.LGA
    region = row.Region
    lon = row.long
    lat = row.lat
    
    # handle the troublesome postcode
    try:
        postcode = int(row.Postcode)
    except:
        postcode = row.Postcode
    
    # form the payload
    market = {
        "name": name,
        "address": address,
        "suburb": suburb ,
        "postcode": postcode,
        "state": state ,
        "business_category": business_category,
        "lga": lga,
        "region": region,
        "lon": lon,
        "lat": lat,
      }
    
    # making the API call
    r = requests.post('https://gfood-api.azurewebsites.net/markets/add', json=market)
    try:
        if r.status_code != 201:
            error.append(row)
            print("ERROR!")
            print(r.json())
        else:
            print(r.json())
    except:
        continue
# Out:
# {'message': 'Market Added', 'addedMarket': {'name': "Ararat Seasonal Farmers' Market", '_id': '5eb7cab9380e65004468f3fe', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cab9380e65004468f3fe'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Bairnsdale Farmers Market', '_id': '5eb7cabc380e65004468f3ff', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cabc380e65004468f3ff'}}}
# {'message': 'Market Added', 'addedMarket': {'name': "Ballarat Lakeside Farmers' Market", '_id': '5eb7cabc380e65004468f400', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cabc380e65004468f400'}}}
# {'message': 'Market Added', 'addedMarket': {'name': "Bendigo Farmers' Market", '_id': '5eb7cabd380e65004468f401', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cabd380e65004468f401'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Big Sams St Albans Market', '_id': '5eb7cabd380e65004468f402', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cabd380e65004468f402'}}}
# {'message': 'Market Added', 'addedMarket': {'name': "Boroondara Farmers' Market", '_id': '5eb7cabe380e65004468f403', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cabe380e65004468f403'}}}
# {'message': 'Market Added', 'addedMarket': {'name': "Bundoora Park Farmers' Market", '_id': '5eb7cabe380e65004468f404', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cabe380e65004468f404'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Buninyong Farmers Market', '_id': '5eb7cabf380e65004468f405', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cabf380e65004468f405'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Camberwell Fresh Food Market', '_id': '5eb7cabf380e65004468f406', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cabf380e65004468f406'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Cardinia Ranges Farmers Market', '_id': '5eb7cac0380e65004468f407', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cac0380e65004468f407'}}}
# {'message': 'Market Added', 'addedMarket': {'name': "Casey Farmers' Market", '_id': '5eb7cac0380e65004468f408', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cac0380e65004468f408'}}}
# {'message': 'Market Added', 'addedMarket': {'name': "Central Geelong Farmers' Market", '_id': '5eb7cac2380e65004468f409', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cac2380e65004468f409'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Central Murray Farmers Market', '_id': '5eb7cac3380e65004468f40a', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cac3380e65004468f40a'}}}
# {'message': 'Market Added', 'addedMarket': {'name': "Churchill Island Farmers' Market", '_id': '5eb7cac3380e65004468f40b', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cac3380e65004468f40b'}}}
# {'message': 'Market Added', 'addedMarket': {'name': "City of Kingston Farmers' Market", '_id': '5eb7cac4380e65004468f40c', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cac4380e65004468f40c'}}}
# {'message': 'Market Added', 'addedMarket': {'name': "Collingwood Farmers' Market", '_id': '5eb7cac4380e65004468f40d', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cac4380e65004468f40d'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Dandenong Market', '_id': '5eb7cac5380e65004468f40e', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cac5380e65004468f40e'}}}
# {'message': 'Market Added', 'addedMarket': {'name': "Daylesford Farmers' Market", '_id': '5eb7cac5380e65004468f40f', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cac5380e65004468f40f'}}}
# {'message': 'Market Added', 'addedMarket': {'name': "East Gippsland Famers' Market", '_id': '5eb7cac6380e65004468f410', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cac6380e65004468f410'}}}
# {'message': 'Market Added', 'addedMarket': {'name': "Gasworks Farmer's Market", '_id': '5eb7cac6380e65004468f411', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cac6380e65004468f411'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Gisborne Farm and Produce Market', '_id': '5eb7cac7380e65004468f412', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cac7380e65004468f412'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Gleadall Street Market', '_id': '5eb7cac7380e65004468f413', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cac7380e65004468f413'}}}
# {'message': 'Market Added', 'addedMarket': {'name': "Heathmont Farmers' Market", '_id': '5eb7cac8380e65004468f414', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cac8380e65004468f414'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Kyneton Farmers Market', '_id': '5eb7cac8380e65004468f415', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cac8380e65004468f415'}}}
# {'message': 'Market Added', 'addedMarket': {'name': "Lake Boga Farmers' Market", '_id': '5eb7cac9380e65004468f416', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cac9380e65004468f416'}}}
# {'message': 'Market Added', 'addedMarket': {'name': "Lancefield District Farmers' Market", '_id': '5eb7cacb380e65004468f417', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cacb380e65004468f417'}}}
# {'message': 'Market Added', 'addedMarket': {'name': "Metung Farmers' Market", '_id': '5eb7cacb380e65004468f418', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cacb380e65004468f418'}}}
# {'message': 'Market Added', 'addedMarket': {'name': "Mornington Farmers' Market", '_id': '5eb7cacc380e65004468f419', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cacc380e65004468f419'}}}
# {'message': 'Market Added', 'addedMarket': {'name': "Moyhu Farmers' Market", '_id': '5eb7cacc380e65004468f41a', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cacc380e65004468f41a'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Oakleigh Market', '_id': '5eb7cacd380e65004468f41b', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cacd380e65004468f41b'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Port Fairy Farmers Market', '_id': '5eb7cacd380e65004468f41c', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cacd380e65004468f41c'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Prahran Market', '_id': '5eb7cace380e65004468f41d', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cace380e65004468f41d'}}}
# {'message': 'Market Added', 'addedMarket': {'name': "Prom Country Farmers' Market", '_id': '5eb7cace380e65004468f41e', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cace380e65004468f41e'}}}
# {'message': 'Market Added', 'addedMarket': {'name': "Slow Food Farmers' Market", '_id': '5eb7cad0380e65004468f41f', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cad0380e65004468f41f'}}}
# {'message': 'Market Added', 'addedMarket': {'name': "South Gippsland Farmers' Market", '_id': '5eb7cad1380e65004468f420', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cad1380e65004468f420'}}}
# {'message': 'Market Added', 'addedMarket': {'name': "Talbot Farmers' Market", '_id': '5eb7cad1380e65004468f421', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cad1380e65004468f421'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Tatong Farmers Market', '_id': '5eb7cad2380e65004468f422', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cad2380e65004468f422'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Templestowe Rotary Farmers Produce Market', '_id': '5eb7cad2380e65004468f423', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cad2380e65004468f423'}}}
# {'message': 'Market Added', 'addedMarket': {'name': "Tolmie Farmers' Market", '_id': '5eb7cad3380e65004468f424', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cad3380e65004468f424'}}}
# {'message': 'Market Added', 'addedMarket': {'name': "Traralgon Farmers' Market", '_id': '5eb7cad5380e65004468f425', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cad5380e65004468f425'}}}
# {'message': 'Market Added', 'addedMarket': {'name': "Veg Out St Kilda Farmers' Market", '_id': '5eb7cad5380e65004468f426', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cad5380e65004468f426'}}}
# {'message': 'Market Added', 'addedMarket': {'name': "Whitehorse Farmers' Market", '_id': '5eb7cad6380e65004468f427', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cad6380e65004468f427'}}}
# {'message': 'Market Added', 'addedMarket': {'name': "Aireys Inlet Farmers' Market", '_id': '5eb7cad6380e65004468f428', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cad6380e65004468f428'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Alexandra Community Produce & Craft Market', '_id': '5eb7cad7380e65004468f429', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cad7380e65004468f429'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Altona Beach Market', '_id': '5eb7cad7380e65004468f42a', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cad7380e65004468f42a'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Apollo Bay Market', '_id': '5eb7cad8380e65004468f42b', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cad8380e65004468f42b'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Bass Community Market', '_id': '5eb7cad8380e65004468f42c', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cad8380e65004468f42c'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Bridge Street Market', '_id': '5eb7cad9380e65004468f42d', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cad9380e65004468f42d'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Ceres Organic Food & Craft Market', '_id': '5eb7cada380e65004468f42e', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cada380e65004468f42e'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Drouin Produce and Craft Market', '_id': '5eb7cada380e65004468f42f', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cada380e65004468f42f'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Footscray Market', '_id': '5eb7cada380e65004468f430', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cada380e65004468f430'}}}
# {'message': 'Market Added', 'addedMarket': {'name': "Girgarre Farmers' Produce Market", '_id': '5eb7cadb380e65004468f431', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cadb380e65004468f431'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Greendale Country Market', '_id': '5eb7cadb380e65004468f432', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cadb380e65004468f432'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Murrabit Country Market', '_id': '5eb7cadc380e65004468f433', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cadc380e65004468f433'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Queen Victoria Market', '_id': '5eb7cadc380e65004468f434', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cadc380e65004468f434'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Red Hill Community Market', '_id': '5eb7cadd380e65004468f435', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cadd380e65004468f435'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Seymour Produce and Craft Market', '_id': '5eb7cadd380e65004468f436', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cadd380e65004468f436'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'South Melbourne Market', '_id': '5eb7cade380e65004468f437', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cade380e65004468f437'}}}
# {'message': 'Market Added', 'addedMarket': {'name': "Stawell Fair Dinkum' Farm and Craft Market", '_id': '5eb7cade380e65004468f438', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cade380e65004468f438'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'The Spa Country Market', '_id': '5eb7cadf380e65004468f439', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cadf380e65004468f439'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Trentham Market', '_id': '5eb7cadf380e65004468f43a', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cadf380e65004468f43a'}}}
# {'message': 'Market Added', 'addedMarket': {'name': "Yarra Valley Farmers' Market", '_id': '5eb7cae0380e65004468f43b', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cae0380e65004468f43b'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Ballan Community Market', '_id': '5eb7cae0380e65004468f43c', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cae0380e65004468f43c'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Ballarat Antique Market', '_id': '5eb7cae1380e65004468f43d', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cae1380e65004468f43d'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Ballarat Fine Art Gallery Arts Market', '_id': '5eb7cae1380e65004468f43e', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cae1380e65004468f43e'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Ballarat Trash & Trivia Market', '_id': '5eb7cae2380e65004468f43f', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cae2380e65004468f43f'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Balnarring Racecourse Rotary Craft Market', '_id': '5eb7cae2380e65004468f440', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cae2380e65004468f440'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Balwyn North Market', '_id': '5eb7cae3380e65004468f441', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cae3380e65004468f441'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Barooga Lions Market', '_id': '5eb7cae3380e65004468f442', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cae3380e65004468f442'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Barwon Heads Market', '_id': '5eb7cae4380e65004468f443', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cae4380e65004468f443'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Bass Valley Lions Market', '_id': '5eb7cae4380e65004468f444', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cae4380e65004468f444'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Bayles Country Market', '_id': '5eb7cae5380e65004468f445', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cae5380e65004468f445'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Bayswater Market', '_id': '5eb7cae5380e65004468f446', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cae5380e65004468f446'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Bealiba Counrty Market', '_id': '5eb7cae6380e65004468f447', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cae6380e65004468f447'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Beaufort Market', '_id': '5eb7cae6380e65004468f448', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cae6380e65004468f448'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Beechworth Country Craft Market', '_id': '5eb7cae7380e65004468f449', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cae7380e65004468f449'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Belmont Market', '_id': '5eb7cae7380e65004468f44a', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cae7380e65004468f44a'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Benalla Lakeside Quality Craft Market', '_id': '5eb7cae8380e65004468f44b', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cae8380e65004468f44b'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Bendigo Market', '_id': '5eb7cae8380e65004468f44c', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cae8380e65004468f44c'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Bendigo Prince of Wales Showground Market', '_id': '5eb7cae9380e65004468f44d', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cae9380e65004468f44d'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Bentleigh Lions Craft Market', '_id': '5eb7cae9380e65004468f44e', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cae9380e65004468f44e'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Bentleigh Rotary Sunday Market', '_id': '5eb7caea380e65004468f44f', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7caea380e65004468f44f'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Berwick Akoonah Park Market', '_id': '5eb7caea380e65004468f450', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7caea380e65004468f450'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Berwick Craft Market', '_id': '5eb7caeb380e65004468f451', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7caeb380e65004468f451'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Birregurra Market', '_id': '5eb7caeb380e65004468f452', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7caeb380e65004468f452'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Bittern Country Market', '_id': '5eb7caec380e65004468f453', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7caec380e65004468f453'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Blackburn Station Art & Craft Market', '_id': '5eb7caec380e65004468f454', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7caec380e65004468f454'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Boneo Community Market', '_id': '5eb7caed380e65004468f455', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7caed380e65004468f455'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Boronia Sunday Market', '_id': '5eb7caef380e65004468f456', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7caef380e65004468f456'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Box Hill Art and Craft Market', '_id': '5eb7caef380e65004468f457', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7caef380e65004468f457'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Briagolong Art and Craft Market', '_id': '5eb7caf0380e65004468f458', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7caf0380e65004468f458'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Bright Craft Market', '_id': '5eb7caf0380e65004468f459', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7caf0380e65004468f459'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Broadford Community and High School Markets', '_id': '5eb7caf1380e65004468f45a', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7caf1380e65004468f45a'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Broadford High School Market', '_id': '5eb7caf1380e65004468f45b', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7caf1380e65004468f45b'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Bruthen Village Market', '_id': '5eb7caf2380e65004468f45c', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7caf2380e65004468f45c'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Bulla Hill Country Market', '_id': '5eb7caf2380e65004468f45d', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7caf2380e65004468f45d'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Bundoora Square Craft Market', '_id': '5eb7caf3380e65004468f45e', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7caf3380e65004468f45e'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Buninyong Lions Club Craft Market', '_id': '5eb7caf3380e65004468f45f', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7caf3380e65004468f45f'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Camberwell Sunday Market', '_id': '5eb7caf4380e65004468f460', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7caf4380e65004468f460'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Camp Street Market', '_id': '5eb7caf4380e65004468f461', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7caf4380e65004468f461'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Campbellfield Market', '_id': '5eb7caf5380e65004468f462', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7caf5380e65004468f462'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Camperdown Rotary Craft Market', '_id': '5eb7caf5380e65004468f463', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7caf5380e65004468f463'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Camperdown Show Society Sunday Market', '_id': '5eb7caf6380e65004468f464', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7caf6380e65004468f464'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Canterbury Craft Market', '_id': '5eb7caf6380e65004468f465', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7caf6380e65004468f465'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Caribbean Gardens Market', '_id': '5eb7caf6380e65004468f466', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7caf6380e65004468f466'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Carisbrook Market', '_id': '5eb7caf7380e65004468f467', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7caf7380e65004468f467'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Caroline Springs Community Market', '_id': '5eb7caf8380e65004468f468', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7caf8380e65004468f468'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Century City Walk Twilight Market', '_id': '5eb7caf8380e65004468f469', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7caf8380e65004468f469'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Chadstone Craft Market', '_id': '5eb7caf9380e65004468f46a', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7caf9380e65004468f46a'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Charlton Lions Club Market', '_id': '5eb7caf9380e65004468f46b', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7caf9380e65004468f46b'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Chelsea Heights Pre-Loved Market', '_id': '5eb7cafa380e65004468f46c', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cafa380e65004468f46c'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Chelsea Trash & Treasure Craft Market', '_id': '5eb7cafa380e65004468f46d', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cafa380e65004468f46d'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Chelsea Trash & Treasure & Craft Market', '_id': '5eb7cafb380e65004468f46e', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cafb380e65004468f46e'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Cheltenham Rotary Market & Car Boot Sale', '_id': '5eb7cafb380e65004468f46f', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cafb380e65004468f46f'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Christmas Hills Community Market & Car Boot Sale', '_id': '5eb7cafd380e65004468f470', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cafd380e65004468f470'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Clunes Country Market', '_id': '5eb7cafd380e65004468f471', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cafd380e65004468f471'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Cobram Lions Log Cabin Market', '_id': '5eb7cafe380e65004468f472', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cafe380e65004468f472'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Coburg Trash & Treasure Market', '_id': '5eb7cafe380e65004468f473', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cafe380e65004468f473'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Colac Lions Club Sunday Market', '_id': '5eb7caff380e65004468f474', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7caff380e65004468f474'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Cowes Market', '_id': '5eb7caff380e65004468f475', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7caff380e65004468f475'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Cowrie Community Market', '_id': '5eb7cb00380e65004468f476', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb00380e65004468f476'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Craigieburn Market', '_id': '5eb7cb00380e65004468f477', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb00380e65004468f477'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Creations at Canterbury Indoor Craft Market', '_id': '5eb7cb01380e65004468f478', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb01380e65004468f478'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Creswick Market', '_id': '5eb7cb01380e65004468f479', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb01380e65004468f479'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Croydon Market', '_id': '5eb7cb02380e65004468f47a', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb02380e65004468f47a'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Dandenong Trash & Treasure Market', '_id': '5eb7cb02380e65004468f47b', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb02380e65004468f47b'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Darley Market', '_id': '5eb7cb03380e65004468f47c', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb03380e65004468f47c'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Daylesford Sunday Market', '_id': '5eb7cb03380e65004468f47d', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb03380e65004468f47d'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Deakin University Market', '_id': '5eb7cb04380e65004468f47e', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb04380e65004468f47e'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Dingley Village Craft Market', '_id': '5eb7cb04380e65004468f47f', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb04380e65004468f47f'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Dromana Drive-In Market', '_id': '5eb7cb04380e65004468f480', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb04380e65004468f480'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Drysdale Community Market', '_id': '5eb7cb05380e65004468f481', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb05380e65004468f481'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Eaglehawk Lions Lakeside Market', '_id': '5eb7cb05380e65004468f482', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb05380e65004468f482'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Echuca Loco Shed Market', '_id': '5eb7cb06380e65004468f483', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb06380e65004468f483'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Eltham Community Market', '_id': '5eb7cb06380e65004468f484', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb06380e65004468f484'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Elwood Market', '_id': '5eb7cb07380e65004468f485', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb07380e65004468f485'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Emerald Art Society Market', '_id': '5eb7cb07380e65004468f486', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb07380e65004468f486'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Epsom Tourist Market', '_id': '5eb7cb08380e65004468f487', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb08380e65004468f487'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Essendon North Market', '_id': '5eb7cb08380e65004468f488', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb08380e65004468f488'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Federation Square Book Market', '_id': '5eb7cb09380e65004468f489', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb09380e65004468f489'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Flemington Racecourse Market', '_id': '5eb7cb0b380e65004468f48a', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb0b380e65004468f48a'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Frankston Karingal Uniting Church Market', '_id': '5eb7cb0b380e65004468f48b', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb0b380e65004468f48b'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Frankston Sunday Market', '_id': '5eb7cb0c380e65004468f48c', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb0c380e65004468f48c'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Garfield Variety Market', '_id': '5eb7cb0c380e65004468f48d', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb0c380e65004468f48d'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Geelong Showgrounds Market', '_id': '5eb7cb0d380e65004468f48e', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb0d380e65004468f48e'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Gembrook Market', '_id': '5eb7cb0d380e65004468f48f', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb0d380e65004468f48f'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Gippsland Craft & Produce Market', '_id': '5eb7cb0e380e65004468f490', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb0e380e65004468f490'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Gisborne Village All Seasons Market', '_id': '5eb7cb0e380e65004468f491', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb0e380e65004468f491'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Grantville Variety Market', '_id': '5eb7cb0f380e65004468f492', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb0f380e65004468f492'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Greensborough Community Market', '_id': '5eb7cb0f380e65004468f493', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb0f380e65004468f493'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Gully Market', '_id': '5eb7cb0f380e65004468f494', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb0f380e65004468f494'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Gumbuya Park Monthly Craft Market', '_id': '5eb7cb10380e65004468f495', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb10380e65004468f495'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Halls Gap Art & Craft Market', '_id': '5eb7cb10380e65004468f496', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb10380e65004468f496'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Hampton Craft Market', '_id': '5eb7cb11380e65004468f497', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb11380e65004468f497'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Hastings on Westernport Craft Market', '_id': '5eb7cb12380e65004468f498', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb12380e65004468f498'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Haven Market', '_id': '5eb7cb12380e65004468f499', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb12380e65004468f499'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Hawthorn Craft Market', '_id': '5eb7cb13380e65004468f49a', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb13380e65004468f49a'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Healesville Community Market', '_id': '5eb7cb13380e65004468f49b', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb13380e65004468f49b'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Healesville Racecourse Market', '_id': '5eb7cb13380e65004468f49c', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb13380e65004468f49c'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Heathcote Bush Market', '_id': '5eb7cb14380e65004468f49d', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb14380e65004468f49d'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Heyfield Market', '_id': '5eb7cb14380e65004468f49e', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb14380e65004468f49e'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Horsham Produce Market', '_id': '5eb7cb15380e65004468f49f', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb15380e65004468f49f'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Inverleigh Market', '_id': '5eb7cb16380e65004468f4a0', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb16380e65004468f4a0'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Inverloch Community Centre Market', '_id': '5eb7cb16380e65004468f4a1', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb16380e65004468f4a1'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Invermay Country Market', '_id': '5eb7cb17380e65004468f4a2', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb17380e65004468f4a2'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Island Craft Market', '_id': '5eb7cb17380e65004468f4a3', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb17380e65004468f4a3'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Jumbunna Bush Market', '_id': '5eb7cb18380e65004468f4a4', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb18380e65004468f4a4'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Junbunna Bush Market', '_id': '5eb7cb18380e65004468f4a5', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb18380e65004468f4a5'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Jung Market', '_id': '5eb7cb19380e65004468f4a6', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb19380e65004468f4a6'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Kallista Community Market', '_id': '5eb7cb19380e65004468f4a7', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb19380e65004468f4a7'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Kerang Community Market', '_id': '5eb7cb19380e65004468f4a8', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb19380e65004468f4a8'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Kilmore Scouts Trackside Market', '_id': '5eb7cb1a380e65004468f4a9', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb1a380e65004468f4a9'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Kongwak Market', '_id': '5eb7cb1a380e65004468f4aa', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb1a380e65004468f4aa'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Kyabram Lions Club Market', '_id': '5eb7cb1b380e65004468f4ab', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb1b380e65004468f4ab'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Kyneton Craft & Junk & Jewel Market', '_id': '5eb7cb1b380e65004468f4ac', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb1b380e65004468f4ac'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'La Trobe University Union Market', '_id': '5eb7cb1c380e65004468f4ad', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb1c380e65004468f4ad'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Lakes Entrance Primary School Community Market', '_id': '5eb7cb1c380e65004468f4ae', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb1c380e65004468f4ae'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Lancefield-Romsey Lions Club Market', '_id': '5eb7cb1d380e65004468f4af', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb1d380e65004468f4af'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Lardner Park Market', '_id': '5eb7cb1d380e65004468f4b0', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb1d380e65004468f4b0'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Latrobe Country Market', '_id': '5eb7cb1e380e65004468f4b1', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb1e380e65004468f4b1'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Laverton Rubble & Riches Market', '_id': '5eb7cb1e380e65004468f4b2', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb1e380e65004468f4b2'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Lilydale Market', '_id': '5eb7cb1f380e65004468f4b3', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb1f380e65004468f4b3'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Loch Sport Health Centre Auxiliary Market', '_id': '5eb7cb1f380e65004468f4b4', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb1f380e65004468f4b4'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Loch Village Market', '_id': '5eb7cb20380e65004468f4b5', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb20380e65004468f4b5'}}}
# ERROR!
# {'error': {'errors': {'name': {'message': 'Error, expected `name` to be unique. Value: `Loch Village Market`', 'name': 'ValidatorError', 'properties': {'message': 'Error, expected `name` to be unique. Value: `Loch Village Market`', 'type': 'unique', 'path': 'name', 'value': 'Loch Village Market'}, 'kind': 'unique', 'path': 'name', 'value': 'Loch Village Market'}}, '_message': 'Market validation failed', 'message': 'Market validation failed: name: Error, expected `name` to be unique. Value: `Loch Village Market`', 'name': 'ValidationError'}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Longwarry Market', '_id': '5eb7cb21380e65004468f4b7', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb21380e65004468f4b7'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Lucknow Primary School Sunday Market', '_id': '5eb7cb21380e65004468f4b8', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb21380e65004468f4b8'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Mansfield Bush Market', '_id': '5eb7cb22380e65004468f4b9', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb22380e65004468f4b9'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Maryborough Sunday Tourist Market', '_id': '5eb7cb22380e65004468f4ba', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb22380e65004468f4ba'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Marysville Community Market', '_id': '5eb7cb22380e65004468f4bb', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb22380e65004468f4bb'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Melbourne Markets', '_id': '5eb7cb23380e65004468f4bc', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb23380e65004468f4bc'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Melbourne University Student Union Market', '_id': '5eb7cb23380e65004468f4bd', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb23380e65004468f4bd'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Melton Sunday Market', '_id': '5eb7cb24380e65004468f4be', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb24380e65004468f4be'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Mentone Sunday Market', '_id': '5eb7cb24380e65004468f4bf', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb24380e65004468f4bf'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Mildura City Heart Market', '_id': '5eb7cb25380e65004468f4c0', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb25380e65004468f4c0'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Milleara Shopping Centre Craft Market', '_id': '5eb7cb25380e65004468f4c1', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb25380e65004468f4c1'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Moe Craft Market', '_id': '5eb7cb26380e65004468f4c2', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb26380e65004468f4c2'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Montrose Craft Market', '_id': '5eb7cb26380e65004468f4c3', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb26380e65004468f4c3'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Moonambel Market', '_id': '5eb7cb27380e65004468f4c4', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb27380e65004468f4c4'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Moonee Ponds Craft Market', '_id': '5eb7cb28380e65004468f4c5', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb28380e65004468f4c5'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Mornington Racecourse Market', '_id': '5eb7cb28380e65004468f4c6', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb28380e65004468f4c6'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Mornington Village Shopping Centre Indoor Market', '_id': '5eb7cb29380e65004468f4c7', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb29380e65004468f4c7'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Mornington Wednesday Market', '_id': '5eb7cb29380e65004468f4c8', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb29380e65004468f4c8'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Mount Beauty Community Market', '_id': '5eb7cb2a380e65004468f4c9', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb2a380e65004468f4c9'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Mount Street Art & Craft Market', '_id': '5eb7cb2a380e65004468f4ca', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb2a380e65004468f4ca'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Mount Waverley Rotary Club Village Market', '_id': '5eb7cb2b380e65004468f4cb', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb2b380e65004468f4cb'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Myrtleford Bush Market', '_id': '5eb7cb2b380e65004468f4cc', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb2b380e65004468f4cc'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Nagambie Lakes Community Market', '_id': '5eb7cb2c380e65004468f4cd', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb2c380e65004468f4cd'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'New Quay Market', '_id': '5eb7cb2c380e65004468f4ce', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb2c380e65004468f4ce'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Newstead Market', '_id': '5eb7cb2d380e65004468f4cf', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb2d380e65004468f4cf'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Numurkah Lions Broken Creek Market', '_id': '5eb7cb2d380e65004468f4d0', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb2d380e65004468f4d0'}}}
# ...
# {'message': 'Market Added', 'addedMarket': {'name': 'Portland Angling Club Sunday Market', '_id': '5eb7cb37380e65004468f4e3', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb37380e65004468f4e3'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Portland Wischmans Market', '_id': '5eb7cb38380e65004468f4e4', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb38380e65004468f4e4'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Preston Market', '_id': '5eb7cb38380e65004468f4e5', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb38380e65004468f4e5'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Queens Gardens Craft and Produce Market', '_id': '5eb7cb39380e65004468f4e6', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb39380e65004468f4e6'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Queenscliff Community Market', '_id': '5eb7cb39380e65004468f4e7', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb39380e65004468f4e7'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Rokeby Community Market', '_id': '5eb7cb3a380e65004468f4e8', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb3a380e65004468f4e8'}}}
# {'message': 'Market Added', 'addedMarket': {'name': "Rose Street Artists' Market", '_id': '5eb7cb3a380e65004468f4e9', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb3a380e65004468f4e9'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Rosebud Community Market', '_id': '5eb7cb3b380e65004468f4ea', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb3b380e65004468f4ea'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Rosedale Monthly Market', '_id': '5eb7cb3b380e65004468f4eb', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb3b380e65004468f4eb'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Rural Christmas Market', '_id': '5eb7cb3c380e65004468f4ec', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb3c380e65004468f4ec'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Rushworth Market', '_id': '5eb7cb3c380e65004468f4ed', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb3c380e65004468f4ed'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Rye Foreshore Market', '_id': '5eb7cb3d380e65004468f4ee', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb3d380e65004468f4ee'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Sale Sunday Charity Variety Market', '_id': '5eb7cb3d380e65004468f4ef', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb3d380e65004468f4ef'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Sandringham Village Craft Market', '_id': '5eb7cb3e380e65004468f4f0', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb3e380e65004468f4f0'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Shepparton Bush Market', '_id': '5eb7cb3e380e65004468f4f1', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb3e380e65004468f4f1'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Shepparton Craft and Produce Market', '_id': '5eb7cb3f380e65004468f4f2', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb3f380e65004468f4f2'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Shepparton Treasure Market', '_id': '5eb7cb3f380e65004468f4f3', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb3f380e65004468f4f3'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Somerville Market', '_id': '5eb7cb40380e65004468f4f4', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb40380e65004468f4f4'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Sophia Mundi Community School Market', '_id': '5eb7cb40380e65004468f4f5', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb40380e65004468f4f5'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'St Andrews Market', '_id': '5eb7cb41380e65004468f4f6', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb41380e65004468f4f6'}}}
# {'message': 'Market Added', 'addedMarket': {'name': "St Anne's Winery Craft Market", '_id': '5eb7cb41380e65004468f4f7', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb41380e65004468f4f7'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'St Kilda Esplanade Market', '_id': '5eb7cb42380e65004468f4f8', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb42380e65004468f4f8'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'St Kilda Night Market', '_id': '5eb7cb42380e65004468f4f9', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb42380e65004468f4f9'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'St Leonards Market', '_id': '5eb7cb43380e65004468f4fa', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb43380e65004468f4fa'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Stawell S.E.S. Market', '_id': '5eb7cb43380e65004468f4fb', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb43380e65004468f4fb'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Steampacket Gardens Art & Craft Market', '_id': '5eb7cb44380e65004468f4fc', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb44380e65004468f4fc'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Sunbury Craft Market', '_id': '5eb7cb44380e65004468f4fd', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb44380e65004468f4fd'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Surrey Hills Neighbourhood Centre Market', '_id': '5eb7cb45380e65004468f4fe', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb45380e65004468f4fe'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Swan Hill Rotary Club Country Market', '_id': '5eb7cb45380e65004468f4ff', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb45380e65004468f4ff'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Tarwin Lower Market', '_id': '5eb7cb46380e65004468f500', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb46380e65004468f500'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'The Campus Monash University Market', '_id': '5eb7cb46380e65004468f501', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb46380e65004468f501'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'The Gardens Market', '_id': '5eb7cb47380e65004468f502', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb47380e65004468f502'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'The Makers Bazaar', '_id': '5eb7cb47380e65004468f503', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb47380e65004468f503'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'The Market at Yarrawood', '_id': '5eb7cb48380e65004468f504', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb48380e65004468f504'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'The Sunday Market', '_id': '5eb7cb48380e65004468f505', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb48380e65004468f505'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Thomastown Market', '_id': '5eb7cb49380e65004468f506', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb49380e65004468f506'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Tongala Market by the Murals', '_id': '5eb7cb49380e65004468f507', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb49380e65004468f507'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Toora Market', '_id': '5eb7cb4a380e65004468f508', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb4a380e65004468f508'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Tooradin Sunday Market', '_id': '5eb7cb4a380e65004468f509', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb4a380e65004468f509'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Tootgarook Community Market', '_id': '5eb7cb4b380e65004468f50a', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb4b380e65004468f50a'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Torquay Primary School Market', '_id': '5eb7cb4b380e65004468f50b', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb4b380e65004468f50b'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Tunstall Square Rotary Market', '_id': '5eb7cb4c380e65004468f50c', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb4c380e65004468f50c'}}}
# {'message': 'Market Added', 'addedMarket': {'name': "Uncle Bob's Country Market", '_id': '5eb7cb4c380e65004468f50d', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb4c380e65004468f50d'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Undercover Weekly Market', '_id': '5eb7cb4d380e65004468f50e', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb4d380e65004468f50e'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Upper Yarra Community Market', '_id': '5eb7cb4d380e65004468f50f', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb4d380e65004468f50f'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Venus Bay Twilight Markets', '_id': '5eb7cb4e380e65004468f510', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb4e380e65004468f510'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Victorian Arts Centre Market', '_id': '5eb7cb4e380e65004468f511', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb4e380e65004468f511'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Violet Town Honeysuckle Community Market', '_id': '5eb7cb4f380e65004468f512', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb4f380e65004468f512'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Wallan Old Time Market', '_id': '5eb7cb4f380e65004468f513', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb4f380e65004468f513'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Wangaratta Trash and Treasure Market', '_id': '5eb7cb50380e65004468f514', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb50380e65004468f514'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Wantirna Trash & Treasure Market', '_id': '5eb7cb50380e65004468f515', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb50380e65004468f515'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Warburton River Market', '_id': '5eb7cb51380e65004468f516', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb51380e65004468f516'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Warrandyte Community Market', '_id': '5eb7cb51380e65004468f517', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb51380e65004468f517'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Warrnambool Hillside Market', '_id': '5eb7cb51380e65004468f518', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb51380e65004468f518'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Warrnambool Undercover Market', '_id': '5eb7cb52380e65004468f519', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb52380e65004468f519'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Wartook Market', '_id': '5eb7cb52380e65004468f51a', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb52380e65004468f51a'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Waterfront City Market', '_id': '5eb7cb53380e65004468f51b', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb53380e65004468f51b'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Wedderburn Market', '_id': '5eb7cb53380e65004468f51c', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb53380e65004468f51c'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Werribee Racecourse Market', '_id': '5eb7cb54380e65004468f51d', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb54380e65004468f51d'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Whittlesea Market', '_id': '5eb7cb54380e65004468f51e', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb54380e65004468f51e'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Williamstown Craft Market', '_id': '5eb7cb55380e65004468f51f', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb55380e65004468f51f'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Windmill Gardens Craft Market', '_id': '5eb7cb56380e65004468f520', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb56380e65004468f520'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Wodonga Market', '_id': '5eb7cb56380e65004468f521', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb56380e65004468f521'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Wonthaggi Rotary Market', '_id': '5eb7cb57380e65004468f522', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb57380e65004468f522'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Woodend Village Market', '_id': '5eb7cb57380e65004468f523', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb57380e65004468f523'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Woori Yallock Primary School Market', '_id': '5eb7cb58380e65004468f524', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb58380e65004468f524'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Yarra Glen Market', '_id': '5eb7cb58380e65004468f525', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb58380e65004468f525'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Yarra Junction Football Club Market', '_id': '5eb7cb59380e65004468f526', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb59380e65004468f526'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Yarram Market', '_id': '5eb7cb59380e65004468f527', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb59380e65004468f527'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Yarrawonga Rotary Market', '_id': '5eb7cb5a380e65004468f528', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb5a380e65004468f528'}}}
# {'message': 'Market Added', 'addedMarket': {'name': 'Yea Community Craft Market', '_id': '5eb7cb5a380e65004468f529', 'request': {'type': 'GET', 'url': 'https://gfood-api.azurewebsites.net/markets/5eb7cb5a380e65004468f529'}}}

# %%
error
# Out:
# [Pandas(Index=184, Name='Loch Village Market', Address='Loch Village Railway Siding', Suburb='Loch (15km west of Korumburra)', Postcode=None, State=None, business_category='Market', LGA=None, Region=None, long=145.7067, lat=-38.3697)]
